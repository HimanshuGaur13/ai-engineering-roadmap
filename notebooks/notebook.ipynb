# %%
print("Hello Himanshu")
# Out:
# Hello Himanshu

# %%
# %run app.py
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/AI_Project/app.py:66
#      63 labels = ["HR", "IT", "Sales"]
#      64 sizes = [20, 50, 30]
# ---> 66 plt.bar(sizes, labels=labels)
#      68 plt.show()
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
# %run app.py
